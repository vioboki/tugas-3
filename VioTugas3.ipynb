# %%
#Memasukkan library yang akan digunakan
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_excel('D:/AnyConv.com__KELOMPOK 7 NEW.xlsx')
# Out:
#         Unnamed: 0  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Unnamed: 9
# 0      responden 1   5   4   2   5   2   5   1   5         NaN
# 1      responden 2   5   4   2   4   3   2   2   5         NaN
# 2      responden 3   5   4   4   5   3   4   3   4         NaN
# 3      responden 4   5   4   5   5   2   4   3   4         NaN
# 4      responden 5   5   4   4   4   2   4   3   5         NaN
# ..             ...  ..  ..  ..  ..  ..  ..  ..  ..         ...
# 495  responden 496   4   3   3   5   5   4   2   2         NaN
# 496  responden 497   5   5   5   5   5   5   1   5         NaN
# 497  responden 498   5   5   5   5   2   5   2   5         NaN
# 498  responden 499   4   2   2   4   2   4   2   4         NaN
# 499  responden 500   4   2   2   3   3   3   3   3         NaN
#
# [500 rows x 10 columns]

# %% [markdown]
# # Data survei

# %%
#menampilkan data responden
data
# Out:
#         Unnamed: 0  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Unnamed: 9
# 0      responden 1   5   4   2   5   2   5   1   5         NaN
# 1      responden 2   5   4   2   4   3   2   2   5         NaN
# 2      responden 3   5   4   4   5   3   4   3   4         NaN
# 3      responden 4   5   4   5   5   2   4   3   4         NaN
# 4      responden 5   5   4   4   4   2   4   3   5         NaN
# ..             ...  ..  ..  ..  ..  ..  ..  ..  ..         ...
# 495  responden 496   4   3   3   5   5   4   2   2         NaN
# 496  responden 497   5   5   5   5   5   5   1   5         NaN
# 497  responden 498   5   5   5   5   2   5   2   5         NaN
# 498  responden 499   4   2   2   4   2   4   2   4         NaN
# 499  responden 500   4   2   2   3   3   3   3   3         NaN
#
# [500 rows x 10 columns]

# %%
#Menampilkan nilai rata-rata dan perhitungan lain
data.describe()
# Out:
#                Q1          Q2          Q3          Q4         Q5          Q6  \
# count  500.000000  500.000000  500.000000  500.000000  500.00000  500.000000
# mean     4.396000    3.558000    3.250000    4.560000    3.40200    4.230000
# std      0.579531    0.955228    1.103601    0.625446    0.93066    0.768297
# min      3.000000    1.000000    1.000000    2.000000    1.00000    1.000000
# 25%      4.000000    3.000000    2.000000    4.000000    3.00000    4.000000
# 50%      4.000000    4.000000    3.000000    5.000000    3.00000    4.000000
# 75%      5.000000    4.000000    4.000000    5.000000    4.00000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.00000    5.000000
#
#                Q7          Q8  Unnamed: 9
# count  500.000000  500.000000         1.0
# mean     2.276000    3.778000         3.0
# std      0.849274    0.813658         NaN
# min      1.000000    1.000000         3.0
# 25%      2.000000    3.000000         3.0
# 50%      2.000000    4.000000         3.0
# 75%      3.000000    4.000000         3.0
# max      5.000000    5.000000         3.0

# %% [markdown]
# # correlation

# %%
corelation = data.corr()
corelation
# Out:
#                   Q1        Q2        Q3        Q4        Q5        Q6  \
# Q1          1.000000  0.291473  0.249102  0.199701  0.094392  0.191106
# Q2          0.291473  1.000000  0.401584  0.079698  0.089814  0.100569
# Q3          0.249102  0.401584  1.000000  0.185814  0.102924  0.047861
# Q4          0.199701  0.079698  0.185814  1.000000  0.097915  0.248557
# Q5          0.094392  0.089814  0.102924  0.097915  1.000000  0.094648
# Q6          0.191106  0.100569  0.047861  0.248557  0.094648  1.000000
# Q7         -0.067786 -0.037064 -0.007484 -0.053875 -0.026562 -0.235692
# Q8          0.246308  0.069457  0.104334  0.146333  0.012232  0.165192
# Unnamed: 9       NaN       NaN       NaN       NaN       NaN       NaN
#
#                   Q7        Q8  Unnamed: 9
# Q1         -0.067786  0.246308         NaN
# Q2         -0.037064  0.069457         NaN
# Q3         -0.007484  0.104334         NaN
# Q4         -0.053875  0.146333         NaN
# Q5         -0.026562  0.012232         NaN
# Q6         -0.235692  0.165192         NaN
# Q7          1.000000  0.013445         NaN
# Q8          0.013445  1.000000         NaN
# Unnamed: 9       NaN       NaN         NaN

# %% [markdown]
# # map correlation

# %%
#Peta Korelasi
#Nilai korelasi yang lebih tinggi ditunjukan dengan warna yang lebih terang
f,ax = plt.subplots(figsize=(40,40))
sns.heatmap(corelation, annot=True, linewidths=.5, fmt='.3f', ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
